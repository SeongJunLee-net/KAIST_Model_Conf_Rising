# %% [markdown]
# # Probability

# %%
import pandas as pd

# %%
total_data = pd.read_csv('./dataset/intervention_data/gpt2_train=False_Total.csv')
total_data
# Out:
#           prob         kl   entropy
# 0    -0.811730  11.324991 -4.458462
# 1    -0.079996  12.253328  0.312050
# 2    -0.873690  11.862528 -6.046141
# 3    -0.629521  12.853862 -4.754339
# 4    -0.086813   0.231026  0.206219
# ...        ...        ...       ...
# 4407 -0.689437  11.481072 -3.619538
# 4408 -0.738699  11.887397 -4.413545
# 4409 -0.063761  10.935291 -0.679931
# 4410 -0.670067  13.116758 -4.840611
# 4411 -0.840015  11.939545 -4.412962
#
# [4412 rows x 3 columns]

# %%
pd.DataFrame(total_data.mean())
# Out:
#                  0
# prob     -0.553152
# kl       11.482063
# entropy  -3.615316

# %%
positive_effect = total_data.loc[total_data['prob']>0].index
negative_effect = total_data.loc[total_data['prob']<0].index

# %%
print(len(positive_effect))
print(len(negative_effect))
# Out:
# 492
# 3920

# %%
display(pd.DataFrame(total_data.iloc[positive_effect].mean()))
display(pd.DataFrame(total_data.iloc[negative_effect].mean()))
# Out:
#                 0
# prob     0.062302
# kl       8.529364
# entropy  0.671864
#                  0
# prob     -0.630398
# kl       11.852657
# entropy  -4.153401

# %% [markdown]
# # Train = False

# %%
data = pd.read_csv('./dataset/intervention_data/gpt2_train=False_edit_prob.csv') 
data
# Out:
#         origin   layer 0   layer 1   layer 2   layer 3   layer 4   layer 5  \
# 0     0.060381  0.077680  0.077977  0.077774  0.078100  0.077841  0.077981
# 1     0.254463  0.227159  0.227489  0.226452  0.226893  0.226157  0.227297
# 2     0.054926  0.070404  0.070347  0.070515  0.070508  0.070475  0.070416
# 3     0.054664  0.052127  0.052066  0.052045  0.052162  0.052134  0.052252
# 4     0.131792  0.169896  0.176724  0.176913  0.176795  0.176403  0.176527
# ...        ...       ...       ...       ...       ...       ...       ...
# 4407  0.078260  0.075132  0.075884  0.077216  0.077128  0.076533  0.076368
# 4408  0.154431  0.135555  0.134931  0.135384  0.133487  0.132775  0.132066
# 4409  0.045767  0.047095  0.047368  0.047312  0.047228  0.047125  0.047146
# 4410  0.323204  0.329298  0.328708  0.329784  0.329894  0.330402  0.330436
# 4411  0.073940  0.075660  0.076013  0.076450  0.076414  0.076361  0.076175
#
#        layer 6   layer 7   layer 8   layer 9  layer 10  layer 11  layer 12
# 0     0.077925  0.077829  0.077788  0.077805  0.077823  0.077876  0.077876
# 1     0.226991  0.227339  0.227099  0.226693  0.226927  0.226868  0.226868
# 2     0.070306  0.070122  0.070187  0.070109  0.070188  0.070239  0.070239
# 3     0.052217  0.052216  0.052173  0.052194  0.052183  0.052167  0.052167
# 4     0.176497  0.176427  0.176438  0.176422  0.176420  0.176529  0.176529
# ...        ...       ...       ...       ...       ...       ...       ...
# 4407  0.076077  0.075982  0.075935  0.075927  0.075923  0.075936  0.075936
# 4408  0.131608  0.131282  0.131009  0.131120  0.131005  0.131177  0.131177
# 4409  0.046868  0.047023  0.047159  0.047136  0.047099  0.047049  0.047049
# 4410  0.330633  0.331016  0.331043  0.330847  0.331140  0.331080  0.331080
# 4411  0.076145  0.076177  0.076064  0.076172  0.076158  0.076138  0.076138
#
# [4412 rows x 14 columns]

# %%
pd.DataFrame(data.mean(axis=0))
# Out:
#                  0
# origin    0.171826
# layer 0   0.173785
# layer 1   0.174060
# layer 2   0.174196
# layer 3   0.174242
# layer 4   0.174224
# layer 5   0.174254
# layer 6   0.174276
# layer 7   0.174332
# layer 8   0.174362
# layer 9   0.174409
# layer 10  0.174470
# layer 11  0.174505
# layer 12  0.174505

# %%
pd.DataFrame(data.loc[positive_effect].mean(axis=0))
# Out:
#                  0
# origin    0.207207
# layer 0   0.209101
# layer 1   0.209752
# layer 2   0.210023
# layer 3   0.210076
# layer 4   0.210046
# layer 5   0.210035
# layer 6   0.210001
# layer 7   0.210026
# layer 8   0.210015
# layer 9   0.210025
# layer 10  0.210073
# layer 11  0.210122
# layer 12  0.210122

# %%
pd.DataFrame(data.loc[negative_effect].mean(axis=0))
# Out:
#                  0
# origin    0.167385
# layer 0   0.169353
# layer 1   0.169580
# layer 2   0.169699
# layer 3   0.169745
# layer 4   0.169728
# layer 5   0.169764
# layer 6   0.169792
# layer 7   0.169852
# layer 8   0.169887
# layer 9   0.169939
# layer 10  0.170001
# layer 11  0.170035
# layer 12  0.170035

# %%
prob_data = pd.read_csv('./dataset/intervention_data/gpt2_train=False_edit_indiv_prob.csv') 
prob_data
# Out:
#         origin   layer 0   layer 1   layer 2   layer 3   layer 4   layer 5  \
# 0     0.060381  0.077680  0.060390  0.060431  0.060863  0.060231  0.060433
# 1     0.254463  0.227159  0.254707  0.253137  0.254759  0.253686  0.255717
# 2     0.054926  0.070404  0.054715  0.054919  0.054746  0.054867  0.054801
# 3     0.054664  0.052127  0.054647  0.054682  0.054779  0.054665  0.054790
# 4     0.131792  0.169896  0.135565  0.132000  0.131786  0.131574  0.131697
# ...        ...       ...       ...       ...       ...       ...       ...
# 4407  0.078260  0.075132  0.079060  0.079566  0.078489  0.077579  0.078131
# 4408  0.154431  0.135555  0.153942  0.154477  0.152271  0.153683  0.153564
# 4409  0.045767  0.047095  0.046103  0.045797  0.045737  0.045679  0.045804
# 4410  0.323204  0.329298  0.322672  0.324720  0.323140  0.323669  0.323208
# 4411  0.073940  0.075660  0.074334  0.074343  0.073946  0.073975  0.073870
#
#        layer 6   layer 7   layer 8   layer 9  layer 10  layer 11  layer 12
# 0     0.060465  0.060251  0.060411  0.060407  0.060426  0.060425  0.060381
# 1     0.253853  0.254936  0.253826  0.253793  0.254956  0.254445  0.254463
# 2     0.054714  0.054768  0.054812  0.054874  0.054924  0.054943  0.054926
# 3     0.054627  0.054650  0.054642  0.054688  0.054668  0.054658  0.054664
# 4     0.131738  0.131782  0.131772  0.131780  0.131744  0.131791  0.131792
# ...        ...       ...       ...       ...       ...       ...       ...
# 4407  0.078033  0.078132  0.078167  0.078173  0.078223  0.078265  0.078260
# 4408  0.153991  0.153996  0.154193  0.154504  0.154278  0.154450  0.154431
# 4409  0.045573  0.045909  0.045881  0.045744  0.045734  0.045708  0.045767
# 4410  0.323453  0.323618  0.323104  0.322990  0.323387  0.323228  0.323204
# 4411  0.073995  0.073998  0.073898  0.074031  0.073960  0.073976  0.073940
#
# [4412 rows x 14 columns]

# %%
display(pd.DataFrame(prob_data.mean(axis=0)))
# Out:
#                  0
# origin    0.171826
# layer 0   0.173785
# layer 1   0.171924
# layer 2   0.171941
# layer 3   0.171876
# layer 4   0.171811
# layer 5   0.171860
# layer 6   0.171857
# layer 7   0.171883
# layer 8   0.171850
# layer 9   0.171871
# layer 10  0.171885
# layer 11  0.171856
# layer 12  0.171826

# %%
display(pd.DataFrame(prob_data.loc[positive_effect].mean(axis=0)))
# Out:
#                  0
# origin    0.207207
# layer 0   0.209101
# layer 1   0.207576
# layer 2   0.207333
# layer 3   0.207237
# layer 4   0.207168
# layer 5   0.207190
# layer 6   0.207187
# layer 7   0.207227
# layer 8   0.207209
# layer 9   0.207217
# layer 10  0.207247
# layer 11  0.207252
# layer 12  0.207207

# %%
display(pd.DataFrame(prob_data.loc[negative_effect].mean(axis=0)))
# Out:
#                  0
# origin    0.167385
# layer 0   0.169353
# layer 1   0.167449
# layer 2   0.167499
# layer 3   0.167438
# layer 4   0.167373
# layer 5   0.167426
# layer 6   0.167423
# layer 7   0.167447
# layer 8   0.167412
# layer 9   0.167434
# layer 10  0.167447
# layer 11  0.167413
# layer 12  0.167385

# %%
import os
os.getcwd()
# Out:
# '/data1/sjlee/NLP/Experiment6'

# %%
display(pd.read_csv('./dataset/intervention_data/gpt2_train=False_edit_accuracy__prob.csv'))
# Out:
#     total_stacked  pos_stacked  neg_stacked  total_indiv  pos_indiv  neg_indiv
# 0        0.060517     0.156504     0.048469     0.060517   0.156504   0.048469
# 1        0.058704     0.154472     0.046684     0.058704   0.154472   0.046684
# 2        0.058250     0.152439     0.046429     0.059837   0.154472   0.047959
# 3        0.058930     0.152439     0.047194     0.060743   0.156504   0.048724
# 4        0.058250     0.152439     0.046429     0.060290   0.156504   0.048214
# 5        0.058250     0.152439     0.046429     0.060063   0.156504   0.047959
# 6        0.057570     0.152439     0.045663     0.060063   0.156504   0.047959
# 7        0.057797     0.152439     0.045918     0.060290   0.156504   0.048214
# 8        0.057344     0.152439     0.045408     0.060517   0.156504   0.048469
# 9        0.057570     0.152439     0.045663     0.060517   0.156504   0.048469
# 10       0.057570     0.152439     0.045663     0.060290   0.156504   0.048214
# 11       0.057570     0.152439     0.045663     0.060517   0.156504   0.048469
# 12       0.057570     0.152439     0.045663     0.060517   0.156504   0.048469
# 13       0.057570     0.152439     0.045663     0.060517   0.156504   0.048469

# %% [markdown]
# # Train=True

# %%
total_data = pd.read_csv('./dataset/intervention_data/gpt2_train=True_Total.csv')
total_data
# Out:
#           prob        kl   entropy
# 0     0.146471  4.069785  6.057753
# 1     0.424571  7.348496  6.174748
# 2     0.992279  9.834436  9.314149
# 3     0.148583  6.131197  5.689916
# 4     0.367218  0.316818  1.718099
# ...        ...       ...       ...
# 4407  0.466487  5.844389  8.094136
# 4408  0.512915  5.370334  7.713697
# 4409  0.380489  8.613902  6.744452
# 4410  0.487833  7.254220  6.955940
# 4411  0.115202  3.830449  5.656858
#
# [4412 rows x 3 columns]

# %%
pd.DataFrame(total_data.mean())
# Out:
#                 0
# prob     0.449066
# kl       6.103899
# entropy  6.316039

# %%
positive_effect = total_data.loc[total_data['prob']>0].index
negative_effect = total_data.loc[total_data['prob']<0].index

# %%
print(len(positive_effect))
print(len(negative_effect))
# Out:
# 4278
# 134

# %%
pd.DataFrame(total_data.iloc[positive_effect].mean())
# Out:
#                 0
# prob     0.466258
# kl       6.204546
# entropy  6.494847

# %%
pd.DataFrame(total_data.iloc[negative_effect].mean())
# Out:
#                 0
# prob    -0.099803
# kl       2.890695
# entropy  0.607537

# %%
data = pd.read_csv('./dataset/intervention_data/gpt2_train=True_edit_prob.csv') 
data
# Out:
#         origin   layer 0   layer 1   layer 2   layer 3   layer 4   layer 5  \
# 0     0.151096  0.148574  0.148499  0.148547  0.148510  0.148480  0.148360
# 1     0.441099  0.285905  0.284253  0.283240  0.282838  0.281082  0.280267
# 2     0.999650  0.999653  0.999654  0.999654  0.999654  0.999654  0.999654
# 3     0.178396  0.128021  0.127509  0.127338  0.127179  0.126979  0.126842
# 4     0.702637  0.797343  0.798701  0.800435  0.801900  0.802946  0.804074
# ...        ...       ...       ...       ...       ...       ...       ...
# 4407  0.475619  0.476396  0.476764  0.477037  0.477453  0.477761  0.478165
# 4408  0.518963  0.513931  0.514009  0.513893  0.514056  0.513978  0.514280
# 4409  0.435542  0.427109  0.426660  0.426251  0.426257  0.427060  0.427752
# 4410  0.500783  0.527932  0.526847  0.526317  0.526437  0.526700  0.526947
# 4411  0.120001  0.131600  0.131715  0.131760  0.131742  0.131683  0.131836
#
#        layer 6   layer 7   layer 8   layer 9  layer 10  layer 11  layer 12
# 0     0.148307  0.148315  0.148238  0.148181  0.148141  0.148146  0.148146
# 1     0.279840  0.279467  0.278786  0.278536  0.278294  0.278032  0.278032
# 2     0.999654  0.999654  0.999654  0.999654  0.999654  0.999654  0.999654
# 3     0.126697  0.126523  0.126444  0.126399  0.126453  0.126391  0.126391
# 4     0.805094  0.806092  0.807020  0.807940  0.808574  0.808929  0.808929
# ...        ...       ...       ...       ...       ...       ...       ...
# 4407  0.478407  0.478671  0.479082  0.479163  0.479221  0.479221  0.479221
# 4408  0.514504  0.514590  0.514454  0.514784  0.514720  0.514734  0.514734
# 4409  0.428296  0.428337  0.428306  0.428286  0.428522  0.428491  0.428491
# 4410  0.527179  0.527021  0.527090  0.526776  0.526796  0.526788  0.526788
# 4411  0.131962  0.132030  0.132242  0.132406  0.132420  0.132453  0.132453
#
# [4412 rows x 14 columns]

# %%
display(pd.DataFrame(data.mean(axis=0)))
# Out:
#                  0
# origin    0.488085
# layer 0   0.490891
# layer 1   0.490939
# layer 2   0.491001
# layer 3   0.491066
# layer 4   0.491121
# layer 5   0.491183
# layer 6   0.491243
# layer 7   0.491297
# layer 8   0.491349
# layer 9   0.491406
# layer 10  0.491464
# layer 11  0.491495
# layer 12  0.491495

# %%
pd.DataFrame(data.loc[positive_effect].mean(axis=0))
# Out:
#                  0
# origin    0.498231
# layer 0   0.497437
# layer 1   0.497444
# layer 2   0.497467
# layer 3   0.497500
# layer 4   0.497529
# layer 5   0.497562
# layer 6   0.497593
# layer 7   0.497622
# layer 8   0.497650
# layer 9   0.497685
# layer 10  0.497726
# layer 11  0.497749
# layer 12  0.497749

# %%
pd.DataFrame(data.loc[negative_effect].mean(axis=0))
# Out:
#                  0
# origin    0.164195
# layer 0   0.281880
# layer 1   0.283254
# layer 2   0.284567
# layer 3   0.285656
# layer 4   0.286556
# layer 5   0.287517
# layer 6   0.288500
# layer 7   0.289378
# layer 8   0.290191
# layer 9   0.290935
# layer 10  0.291520
# layer 11  0.291836
# layer 12  0.291836

# %%
prob_data = pd.read_csv('./dataset/intervention_data/gpt2_train=True_edit_indiv_prob.csv') 
prob_data
# Out:
#         origin   layer 0   layer 1   layer 2   layer 3   layer 4   layer 5  \
# 0     0.151096  0.148574  0.151031  0.151090  0.151073  0.151103  0.151016
# 1     0.441099  0.285905  0.439605  0.440649  0.441022  0.439407  0.440425
# 2     0.999650  0.999653  0.999651  0.999651  0.999649  0.999650  0.999650
# 3     0.178396  0.128021  0.178244  0.178260  0.178269  0.178275  0.178260
# 4     0.702637  0.797343  0.704513  0.704883  0.704610  0.704103  0.704178
# ...        ...       ...       ...       ...       ...       ...       ...
# 4407  0.475619  0.476396  0.475419  0.475506  0.475475  0.475524  0.475626
# 4408  0.518963  0.513931  0.519437  0.518876  0.519056  0.518873  0.519248
# 4409  0.435542  0.427109  0.436211  0.436000  0.435492  0.434393  0.434398
# 4410  0.500783  0.527932  0.499887  0.500302  0.500915  0.501074  0.501124
# 4411  0.120001  0.131600  0.120115  0.120068  0.120057  0.120042  0.120077
#
#        layer 6   layer 7   layer 8   layer 9  layer 10  layer 11  layer 12
# 0     0.151051  0.151108  0.151022  0.151059  0.151098  0.151090  0.151096
# 1     0.440957  0.440929  0.440710  0.440979  0.441083  0.440900  0.441099
# 2     0.999650  0.999650  0.999650  0.999650  0.999650  0.999650  0.999650
# 3     0.178283  0.178293  0.178429  0.178386  0.178365  0.178355  0.178396
# 4     0.704072  0.704114  0.703847  0.703909  0.703594  0.703197  0.702637
# ...        ...       ...       ...       ...       ...       ...       ...
# 4407  0.475548  0.475649  0.475516  0.475626  0.475698  0.475644  0.475619
# 4408  0.519318  0.519179  0.519108  0.519176  0.518951  0.518984  0.518963
# 4409  0.434836  0.435592  0.435581  0.435836  0.435192  0.435482  0.435542
# 4410  0.501161  0.500684  0.500790  0.500508  0.500813  0.500797  0.500783
# 4411  0.120110  0.120078  0.120141  0.120142  0.120067  0.120052  0.120001
#
# [4412 rows x 14 columns]

# %%
pd.DataFrame(prob_data.mean(axis=0))
# Out:
#                  0
# origin    0.488085
# layer 0   0.490891
# layer 1   0.488128
# layer 2   0.488131
# layer 3   0.488134
# layer 4   0.488140
# layer 5   0.488142
# layer 6   0.488133
# layer 7   0.488129
# layer 8   0.488129
# layer 9   0.488127
# layer 10  0.488129
# layer 11  0.488106
# layer 12  0.488085

# %%
pd.DataFrame(prob_data.loc[positive_effect].mean(axis=0))
# Out:
#                  0
# origin    0.498231
# layer 0   0.497437
# layer 1   0.498250
# layer 2   0.498255
# layer 3   0.498262
# layer 4   0.498271
# layer 5   0.498272
# layer 6   0.498262
# layer 7   0.498260
# layer 8   0.498261
# layer 9   0.498261
# layer 10  0.498265
# layer 11  0.498246
# layer 12  0.498231

# %%
pd.DataFrame(prob_data.loc[negative_effect].mean(axis=0))
# Out:
#                  0
# origin    0.164195
# layer 0   0.281880
# layer 1   0.164972
# layer 2   0.164909
# layer 3   0.164786
# layer 4   0.164700
# layer 5   0.164731
# layer 6   0.164740
# layer 7   0.164680
# layer 8   0.164645
# layer 9   0.164617
# layer 10  0.164536
# layer 11  0.164374
# layer 12  0.164195

# %%
display(pd.read_csv('./dataset/intervention_data/gpt2_train=True_edit_accuracy__prob.csv'))
# Out:
#     total_stacked  pos_stacked  neg_stacked  total_indiv  pos_indiv  neg_indiv
# 0        0.420444     0.431744     0.059701     0.420444   0.431744   0.059701
# 1        0.415684     0.425900     0.089552     0.415684   0.425900   0.089552
# 2        0.415684     0.425900     0.089552     0.420898   0.431978   0.067164
# 3        0.415005     0.425199     0.089552     0.420671   0.431744   0.067164
# 4        0.414778     0.424965     0.089552     0.420671   0.431744   0.067164
# 5        0.415005     0.425199     0.089552     0.420444   0.431744   0.059701
# 6        0.414551     0.424731     0.089552     0.420671   0.431744   0.067164
# 7        0.414551     0.424731     0.089552     0.420444   0.431744   0.059701
# 8        0.414551     0.424731     0.089552     0.420444   0.431744   0.059701
# 9        0.414551     0.424731     0.089552     0.420671   0.431744   0.067164
# 10       0.414551     0.424731     0.089552     0.420444   0.431744   0.059701
# 11       0.414551     0.424731     0.089552     0.420444   0.431744   0.059701
# 12       0.414325     0.424497     0.089552     0.420444   0.431744   0.059701
# 13       0.414325     0.424497     0.089552     0.420444   0.431744   0.059701
