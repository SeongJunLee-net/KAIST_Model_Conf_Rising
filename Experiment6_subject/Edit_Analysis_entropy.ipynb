# %% [markdown]
# # Entropy

# %%
import pandas as pd

# %%
total_data = pd.read_csv('./dataset/intervention_data/gpt2_train=False_Total.csv')
total_data
# Out:
#           prob         kl   entropy
# 0    -0.811730  11.324991 -4.458462
# 1    -0.079996  12.253328  0.312050
# 2    -0.873690  11.862528 -6.046141
# 3    -0.629521  12.853862 -4.754339
# 4    -0.086813   0.231026  0.206219
# ...        ...        ...       ...
# 4407 -0.689437  11.481072 -3.619538
# 4408 -0.738699  11.887397 -4.413545
# 4409 -0.063761  10.935291 -0.679931
# 4410 -0.670067  13.116758 -4.840611
# 4411 -0.840015  11.939545 -4.412962
#
# [4412 rows x 3 columns]

# %%
pd.DataFrame(total_data.mean())
# Out:
#                  0
# prob     -0.553152
# kl       11.482063
# entropy  -3.615316

# %%
positive_effect = total_data.loc[total_data['entropy']>0].index
negative_effect = total_data.loc[total_data['entropy']<0].index

# %%
print(len(positive_effect))
print(len(negative_effect))
# Out:
# 648
# 3764

# %%
display(pd.DataFrame(total_data.iloc[positive_effect].mean()))
display(pd.DataFrame(total_data.iloc[negative_effect].mean()))
# Out:
#                 0
# prob     0.020973
# kl       7.218677
# entropy  0.685539
#                  0
# prob     -0.651992
# kl       12.216036
# entropy  -4.355740

# %% [markdown]
# # Train = False

# %%
data = pd.read_csv('./dataset/intervention_data/gpt2_train=False_edit_entropy.csv') 
data
# Out:
#         origin   layer 0   layer 1   layer 2   layer 3   layer 4   layer 5  \
# 0     5.585329  5.735362  5.734117  5.727365  5.723575  5.726037  5.726032
# 1     4.494078  4.713180  4.711165  4.715771  4.691876  4.694017  4.680737
# 2     6.701682  6.620500  6.621330  6.617580  6.620285  6.618822  6.619115
# 3     7.300532  7.355549  7.356816  7.357226  7.359301  7.359872  7.360093
# 4     4.760793  4.664572  4.629326  4.623162  4.622767  4.622755  4.621744
# ...        ...       ...       ...       ...       ...       ...       ...
# 4407  5.512606  5.584816  5.596092  5.600953  5.601455  5.592260  5.587379
# 4408  5.374681  5.450512  5.447980  5.449475  5.448450  5.445925  5.443941
# 4409  6.837010  6.829961  6.826391  6.822598  6.823729  6.823771  6.822313
# 4410  4.915978  4.820156  4.829470  4.815117  4.817516  4.811721  4.811417
# 4411  5.205304  5.215442  5.216845  5.221620  5.222687  5.220883  5.219511
#
#        layer 6   layer 7   layer 8   layer 9  layer 10  layer 11  layer 12
# 0     5.722651  5.720128  5.720375  5.720791  5.720630  5.720444  5.720444
# 1     4.672327  4.657249  4.654314  4.657695  4.655547  4.654179  4.654179
# 2     6.620498  6.619890  6.619541  6.619303  6.619324  6.618773  6.618773
# 3     7.361228  7.361173  7.361464  7.361296  7.361431  7.361553  7.361553
# 4     4.621282  4.620514  4.620368  4.620687  4.620756  4.620950  4.620950
# ...        ...       ...       ...       ...       ...       ...       ...
# 4407  5.583329  5.582408  5.581565  5.581544  5.581308  5.581612  5.581612
# 4408  5.442153  5.443159  5.444778  5.444743  5.445116  5.444694  5.444694
# 4409  6.822396  6.818534  6.814637  6.813507  6.812460  6.811532  6.811532
# 4410  4.810665  4.804221  4.806293  4.806704  4.805601  4.805470  4.805470
# 4411  5.220148  5.220350  5.218708  5.218741  5.218320  5.218353  5.218353
#
# [4412 rows x 14 columns]

# %%
pd.DataFrame(data.mean(axis=0))
# Out:
#                  0
# origin    5.639613
# layer 0   5.632793
# layer 1   5.631896
# layer 2   5.630979
# layer 3   5.629602
# layer 4   5.629042
# layer 5   5.628322
# layer 6   5.627141
# layer 7   5.625700
# layer 8   5.624598
# layer 9   5.623618
# layer 10  5.622839
# layer 11  5.622435
# layer 12  5.622435

# %%
pd.DataFrame(data.loc[positive_effect].mean(axis=0))
# Out:
#                  0
# origin    5.223690
# layer 0   5.151664
# layer 1   5.139903
# layer 2   5.134541
# layer 3   5.131678
# layer 4   5.130661
# layer 5   5.129275
# layer 6   5.127316
# layer 7   5.125556
# layer 8   5.123773
# layer 9   5.122482
# layer 10  5.121333
# layer 11  5.120286
# layer 12  5.120286

# %%
pd.DataFrame(data.loc[negative_effect].mean(axis=0))
# Out:
#                  0
# origin    5.711217
# layer 0   5.715623
# layer 1   5.716596
# layer 2   5.716444
# layer 3   5.715323
# layer 4   5.714842
# layer 5   5.714236
# layer 6   5.713190
# layer 7   5.711803
# layer 8   5.710819
# layer 9   5.709892
# layer 10  5.709177
# layer 11  5.708883
# layer 12  5.708883

# %%
prob_data = pd.read_csv('./dataset/intervention_data/gpt2_train=False_edit_indiv_entropy.csv') 
prob_data
# Out:
#         origin   layer 0   layer 1   layer 2   layer 3   layer 4   layer 5  \
# 0     5.585329  5.735362  5.587139  5.578952  5.585560  5.587091  5.583788
# 1     4.494078  4.713180  4.488909  4.496979  4.473365  4.497070  4.478295
# 2     6.701682  6.620500  6.702745  6.700830  6.703600  6.702547  6.701156
# 3     7.300532  7.355549  7.302786  7.300205  7.302836  7.300620  7.300465
# 4     4.760793  4.664572  4.730679  4.755069  4.760149  4.760823  4.759913
# ...        ...       ...       ...       ...       ...       ...       ...
# 4407  5.512606  5.584816  5.530486  5.519447  5.515943  5.504439  5.508370
# 4408  5.374681  5.450512  5.375250  5.375643  5.375353  5.371167  5.374284
# 4409  6.837010  6.829961  6.832522  6.833066  6.838572  6.836483  6.836201
# 4410  4.915978  4.820156  4.925842  4.896777  4.917765  4.910245  4.915232
# 4411  5.205304  5.215442  5.209152  5.210531  5.206855  5.205054  5.204491
#
#        layer 6   layer 7   layer 8   layer 9  layer 10  layer 11  layer 12
# 0     5.582866  5.582618  5.585108  5.585829  5.585732  5.586172  5.585329
# 1     4.488946  4.480523  4.491988  4.496758  4.492999  4.492404  4.494078
# 2     6.703752  6.702669  6.702097  6.702236  6.701854  6.701188  6.701682
# 3     7.301483  7.300802  7.300614  7.300648  7.300714  7.300467  7.300532
# 4     4.761114  4.760674  4.760756  4.761064  4.760939  4.760903  4.760793
# ...        ...       ...       ...       ...       ...       ...       ...
# 4407  5.509300  5.511993  5.512401  5.512779  5.512845  5.512973  5.512606
# 4408  5.373390  5.375833  5.376336  5.374372  5.374997  5.374671  5.374681
# 4409  6.837218  6.833554  6.833438  6.835553  6.836215  6.836037  6.837010
# 4410  4.913819  4.910243  4.916944  4.917542  4.914409  4.915951  4.915978
# 4411  5.206020  5.206094  5.204025  5.205057  5.204818  5.204988  5.205304
#
# [4412 rows x 14 columns]

# %%
display(pd.DataFrame(prob_data.mean(axis=0)))
# Out:
#                  0
# origin    5.639613
# layer 0   5.632793
# layer 1   5.638875
# layer 2   5.638722
# layer 3   5.638344
# layer 4   5.639000
# layer 5   5.638785
# layer 6   5.638383
# layer 7   5.638150
# layer 8   5.638501
# layer 9   5.638633
# layer 10  5.638848
# layer 11  5.639252
# layer 12  5.639613

# %%
display(pd.DataFrame(prob_data.loc[positive_effect].mean(axis=0)))
# Out:
#                  0
# origin    5.223690
# layer 0   5.151664
# layer 1   5.211600
# layer 2   5.218606
# layer 3   5.220936
# layer 4   5.222457
# layer 5   5.222307
# layer 6   5.221713
# layer 7   5.221950
# layer 8   5.221966
# layer 9   5.222413
# layer 10  5.222601
# layer 11  5.222780
# layer 12  5.223690

# %%
display(pd.DataFrame(prob_data.loc[negative_effect].mean(axis=0)))
# Out:
#                  0
# origin    5.711217
# layer 0   5.715623
# layer 1   5.712434
# layer 2   5.711048
# layer 3   5.710204
# layer 4   5.710711
# layer 5   5.710485
# layer 6   5.710116
# layer 7   5.709802
# layer 8   5.710211
# layer 9   5.710288
# layer 10  5.710508
# layer 11  5.710951
# layer 12  5.711217

# %%
display(pd.read_csv('./dataset/intervention_data/gpt2_train=False_edit_accuracy__entropy.csv'))
# Out:
#     total_stacked  pos_stacked  neg_stacked  total_indiv  pos_indiv  neg_indiv
# 0        0.060517     0.158951     0.043571     0.060517   0.158951   0.043571
# 1        0.059383     0.151235     0.043571     0.059383   0.151235   0.043571
# 2        0.059383     0.151235     0.043571     0.059837   0.155864   0.043305
# 3        0.059383     0.151235     0.043571     0.060743   0.157407   0.044102
# 4        0.058930     0.151235     0.043039     0.060290   0.158951   0.043305
# 5        0.058704     0.151235     0.042774     0.060290   0.158951   0.043305
# 6        0.058704     0.151235     0.042774     0.060290   0.158951   0.043305
# 7        0.058704     0.151235     0.042774     0.060290   0.158951   0.043305
# 8        0.058477     0.151235     0.042508     0.060517   0.158951   0.043571
# 9        0.058477     0.151235     0.042508     0.060517   0.158951   0.043571
# 10       0.058930     0.151235     0.043039     0.060290   0.158951   0.043305
# 11       0.058930     0.151235     0.043039     0.060517   0.158951   0.043571
# 12       0.058704     0.151235     0.042774     0.060290   0.157407   0.043571
# 13       0.058704     0.151235     0.042774     0.060517   0.158951   0.043571

# %% [markdown]
# # Train=True

# %%
total_data = pd.read_csv('./dataset/intervention_data/gpt2_train=True_Total.csv')
total_data
# Out:
#           prob        kl   entropy
# 0     0.146471  4.069785  6.057753
# 1     0.424571  7.348496  6.174748
# 2     0.992279  9.834436  9.314149
# 3     0.148583  6.131197  5.689916
# 4     0.367218  0.316818  1.718099
# ...        ...       ...       ...
# 4407  0.466487  5.844389  8.094136
# 4408  0.512915  5.370334  7.713697
# 4409  0.380489  8.613902  6.744452
# 4410  0.487833  7.254220  6.955940
# 4411  0.115202  3.830449  5.656858
#
# [4412 rows x 3 columns]

# %%
pd.DataFrame(total_data.mean())
# Out:
#                 0
# prob     0.449066
# kl       6.103899
# entropy  6.316039

# %%
positive_effect = total_data.loc[total_data['entropy']>0].index
negative_effect = total_data.loc[total_data['entropy']<0].index

# %%
print(len(positive_effect))
print(len(negative_effect))
# Out:
# 4380
# 32

# %%
pd.DataFrame(total_data.iloc[positive_effect].mean())
# Out:
#                 0
# prob     0.453219
# kl       6.140617
# entropy  6.364427

# %%
pd.DataFrame(total_data.iloc[negative_effect].mean())
# Out:
#                 0
# prob    -0.119383
# kl       1.078142
# entropy -0.307074

# %%
data = pd.read_csv('./dataset/intervention_data/gpt2_train=True_edit_entropy.csv') 
data
# Out:
#         origin   layer 0   layer 1   layer 2   layer 3   layer 4   layer 5  \
# 0     3.528265  3.521721  3.521814  3.521848  3.521238  3.520104  3.519717
# 1     2.600141  2.618376  2.620991  2.621385  2.621457  2.623670  2.623000
# 2     0.003354  0.003429  0.003423  0.003424  0.003427  0.003422  0.003424
# 3     3.006993  3.160550  3.161080  3.161552  3.161619  3.161915  3.162092
# 4     1.864189  1.450888  1.444196  1.436157  1.428722  1.424944  1.420210
# ...        ...       ...       ...       ...       ...       ...       ...
# 4407  1.259484  1.267210  1.267491  1.267336  1.267311  1.266919  1.266557
# 4408  1.717130  1.824092  1.826018  1.827146  1.825697  1.825115  1.823407
# 4409  1.729754  1.806397  1.805315  1.804121  1.803932  1.802214  1.800972
# 4410  2.038868  1.673145  1.672540  1.671030  1.669317  1.667376  1.666042
# 4411  3.894019  3.910935  3.911464  3.911633  3.910311  3.909020  3.908665
#
#        layer 6   layer 7   layer 8   layer 9  layer 10  layer 11  layer 12
# 0     3.518991  3.518725  3.518387  3.518263  3.518209  3.518326  3.518326
# 1     2.621939  2.620438  2.621132  2.621491  2.621843  2.623084  2.623084
# 2     0.003425  0.003423  0.003426  0.003425  0.003427  0.003424  0.003424
# 3     3.162045  3.162236  3.161757  3.161524  3.161073  3.161081  3.161081
# 4     1.415997  1.411819  1.408872  1.404904  1.402164  1.401273  1.401273
# ...        ...       ...       ...       ...       ...       ...       ...
# 4407  1.266245  1.265689  1.265387  1.265120  1.264995  1.264754  1.264754
# 4408  1.821329  1.818412  1.818824  1.817167  1.816514  1.815868  1.815868
# 4409  1.799851  1.798620  1.797082  1.795845  1.795592  1.795240  1.795240
# 4410  1.665167  1.664963  1.664087  1.664405  1.663875  1.663988  1.663988
# 4411  3.908175  3.907599  3.907125  3.906975  3.906848  3.906771  3.906771
#
# [4412 rows x 14 columns]

# %%
display(pd.DataFrame(data.mean(axis=0)))
# Out:
#                  0
# origin    2.517279
# layer 0   2.481150
# layer 1   2.480570
# layer 2   2.479952
# layer 3   2.479494
# layer 4   2.478911
# layer 5   2.478373
# layer 6   2.477853
# layer 7   2.477366
# layer 8   2.476831
# layer 9   2.476443
# layer 10  2.476046
# layer 11  2.475906
# layer 12  2.475906

# %%
pd.DataFrame(data.loc[positive_effect].mean(axis=0))
# Out:
#                  0
# origin    2.502715
# layer 0   2.473226
# layer 1   2.472706
# layer 2   2.472139
# layer 3   2.471718
# layer 4   2.471156
# layer 5   2.470648
# layer 6   2.470157
# layer 7   2.469696
# layer 8   2.469186
# layer 9   2.468820
# layer 10  2.468442
# layer 11  2.468312
# layer 12  2.468312

# %%
pd.DataFrame(data.loc[negative_effect].mean(axis=0))
# Out:
#                  0
# origin    4.510676
# layer 0   3.565773
# layer 1   3.556935
# layer 2   3.549369
# layer 3   3.543909
# layer 4   3.540420
# layer 5   3.535780
# layer 6   3.531271
# layer 7   3.527210
# layer 8   3.523368
# layer 9   3.519731
# layer 10  3.516857
# layer 11  3.515368
# layer 12  3.515368

# %%
prob_data = pd.read_csv('./dataset/intervention_data/gpt2_train=True_edit_indiv_entropy.csv') 
prob_data
# Out:
#         origin   layer 0   layer 1   layer 2   layer 3   layer 4   layer 5  \
# 0     3.528265  3.521721  3.528599  3.528452  3.528056  3.527596  3.527971
# 1     2.600141  2.618376  2.601517  2.598723  2.597307  2.601587  2.597455
# 2     0.003354  0.003429  0.003357  0.003355  0.003356  0.003356  0.003357
# 3     3.006993  3.160550  3.007153  3.007303  3.007155  3.007374  3.007026
# 4     1.864189  1.450888  1.856929  1.854714  1.855340  1.859796  1.858282
# ...        ...       ...       ...       ...       ...       ...       ...
# 4407  1.259484  1.267210  1.259953  1.259550  1.259511  1.259708  1.259365
# 4408  1.717130  1.824092  1.718226  1.717751  1.716539  1.716900  1.715672
# 4409  1.729754  1.806397  1.727916  1.728338  1.729709  1.729589  1.729825
# 4410  2.038868  1.673145  2.037491  2.036808  2.037174  2.036766  2.037312
# 4411  3.894019  3.910935  3.893975  3.893730  3.892330  3.892818  3.893283
#
#        layer 6   layer 7   layer 8   layer 9  layer 10  layer 11  layer 12
# 0     3.527981  3.527896  3.528143  3.527993  3.528281  3.528135  3.528265
# 1     2.597361  2.596442  2.600567  2.599212  2.600291  2.601191  2.600141
# 2     0.003355  0.003356  0.003355  0.003355  0.003356  0.003356  0.003354
# 3     3.006824  3.007068  3.006792  3.006921  3.006888  3.006985  3.006993
# 4     1.859238  1.859194  1.860428  1.859322  1.860794  1.862657  1.864189
# ...        ...       ...       ...       ...       ...       ...       ...
# 4407  1.259367  1.259198  1.259397  1.259321  1.259309  1.259262  1.259484
# 4408  1.716482  1.715922  1.716588  1.716403  1.717005  1.716508  1.717130
# 4409  1.729330  1.728963  1.728824  1.728586  1.729625  1.729777  1.729754
# 4410  2.037266  2.037972  2.037592  2.038832  2.038597  2.038781  2.038868
# 4411  3.893519  3.893673  3.893361  3.893326  3.893435  3.893915  3.894019
#
# [4412 rows x 14 columns]

# %%
pd.DataFrame(prob_data.mean(axis=0))
# Out:
#                  0
# origin    2.517279
# layer 0   2.481150
# layer 1   2.516409
# layer 2   2.516503
# layer 3   2.516790
# layer 4   2.516630
# layer 5   2.516629
# layer 6   2.516652
# layer 7   2.516717
# layer 8   2.516660
# layer 9   2.516848
# layer 10  2.516873
# layer 11  2.517124
# layer 12  2.517279

# %%
pd.DataFrame(prob_data.loc[positive_effect].mean(axis=0))
# Out:
#                  0
# origin    2.502715
# layer 0   2.473226
# layer 1   2.501893
# layer 2   2.501977
# layer 3   2.502250
# layer 4   2.502079
# layer 5   2.502088
# layer 6   2.502111
# layer 7   2.502175
# layer 8   2.502116
# layer 9   2.502303
# layer 10  2.502324
# layer 11  2.502568
# layer 12  2.502715

# %%
pd.DataFrame(prob_data.loc[negative_effect].mean(axis=0))
# Out:
#                  0
# origin    4.510676
# layer 0   3.565773
# layer 1   4.503243
# layer 2   4.504741
# layer 3   4.506919
# layer 4   4.508260
# layer 5   4.506929
# layer 6   4.507028
# layer 7   4.507052
# layer 8   4.507373
# layer 9   4.507625
# layer 10  4.508275
# layer 11  4.509503
# layer 12  4.510676

# %%
display(pd.read_csv('./dataset/intervention_data/gpt2_train=True_edit_accuracy__entropy.csv'))
# Out:
#     total_stacked  pos_stacked  neg_stacked  total_indiv  pos_indiv  neg_indiv
# 0        0.420444     0.422831      0.09375     0.420444   0.422831    0.09375
# 1        0.415458     0.418037      0.06250     0.415458   0.418037    0.06250
# 2        0.415231     0.417808      0.06250     0.420898   0.423288    0.09375
# 3        0.415231     0.417808      0.06250     0.420671   0.423059    0.09375
# 4        0.415231     0.417808      0.06250     0.420671   0.423059    0.09375
# 5        0.415231     0.417808      0.06250     0.420444   0.422831    0.09375
# 6        0.415231     0.417808      0.06250     0.420671   0.423059    0.09375
# 7        0.415231     0.417808      0.06250     0.420444   0.422831    0.09375
# 8        0.415231     0.417808      0.06250     0.420444   0.422831    0.09375
# 9        0.415231     0.417808      0.06250     0.420671   0.423059    0.09375
# 10       0.415005     0.417580      0.06250     0.420444   0.422831    0.09375
# 11       0.415005     0.417580      0.06250     0.420444   0.422831    0.09375
# 12       0.415005     0.417580      0.06250     0.420444   0.422831    0.09375
# 13       0.415005     0.417580      0.06250     0.420444   0.422831    0.09375
