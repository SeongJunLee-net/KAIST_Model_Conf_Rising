# %% [markdown]
# # Probability

# %%
import pandas as pd

# %%
total_data = pd.read_csv('./dataset/intervention_data/gpt2_train=False_Total.csv')
total_data
# Out:
#           prob         kl   entropy
# 0    -0.811730  11.324991 -4.458462
# 1    -0.079996  12.253328  0.312050
# 2    -0.873690  11.862528 -6.046141
# 3    -0.629521  12.853862 -4.754339
# 4    -0.086813   0.231026  0.206219
# ...        ...        ...       ...
# 4407 -0.689437  11.481072 -3.619538
# 4408 -0.738699  11.887397 -4.413545
# 4409 -0.063761  10.935291 -0.679931
# 4410 -0.670067  13.116758 -4.840611
# 4411 -0.840015  11.939545 -4.412962
#
# [4412 rows x 3 columns]

# %%
pd.DataFrame(total_data.mean())
# Out:
#                  0
# prob     -0.553152
# kl       11.482063
# entropy  -3.615316

# %%
positive_effect = total_data.loc[total_data['prob']>0].index
negative_effect = total_data.loc[total_data['prob']<0].index

# %%
print(len(positive_effect))
print(len(negative_effect))
# Out:
# 492
# 3920

# %%
display(pd.DataFrame(total_data.iloc[positive_effect].mean()))
display(pd.DataFrame(total_data.iloc[negative_effect].mean()))
# Out:
#                 0
# prob     0.062302
# kl       8.529364
# entropy  0.671864
#                  0
# prob     -0.630398
# kl       11.852657
# entropy  -4.153401

# %% [markdown]
# # Train = False

# %%
data = pd.read_csv('./dataset/intervention_data/gpt2_train=False_edit_prob.csv') 
data
# Out:
#         origin   layer 0   layer 1   layer 2   layer 3   layer 4   layer 5  \
# 0     0.060381  0.082839  0.082910  0.084086  0.086971  0.088865  0.090088
# 1     0.254463  0.250577  0.250930  0.249574  0.250931  0.254645  0.260396
# 2     0.054926  0.068459  0.068352  0.069874  0.070698  0.070840  0.070866
# 3     0.054664  0.058539  0.058401  0.058144  0.059220  0.059777  0.059780
# 4     0.131792  0.131748  0.143225  0.148980  0.153286  0.157985  0.164601
# ...        ...       ...       ...       ...       ...       ...       ...
# 4407  0.078260  0.114105  0.114114  0.116750  0.118678  0.120557  0.121441
# 4408  0.154431  0.193971  0.193586  0.197486  0.201052  0.206405  0.210142
# 4409  0.045767  0.054514  0.056527  0.056970  0.057746  0.059304  0.059596
# 4410  0.323204  0.415390  0.417636  0.423705  0.432157  0.439778  0.447795
# 4411  0.073940  0.111856  0.112052  0.114822  0.116791  0.119372  0.120978
#
#        layer 6   layer 7   layer 8   layer 9  layer 10  layer 11  layer 12
# 0     0.089064  0.089202  0.087861  0.087318  0.086384  0.085524  0.087590
# 1     0.262485  0.263200  0.265611  0.268920  0.268349  0.267870  0.268710
# 2     0.070625  0.069492  0.068210  0.068046  0.067903  0.067577  0.068355
# 3     0.059629  0.059393  0.058665  0.058101  0.057967  0.057899  0.058304
# 4     0.174659  0.188140  0.202661  0.218273  0.235327  0.252396  0.273630
# ...        ...       ...       ...       ...       ...       ...       ...
# 4407  0.120668  0.120647  0.121421  0.122585  0.123111  0.123850  0.125016
# 4408  0.210440  0.209322  0.208864  0.208806  0.208948  0.209472  0.212120
# 4409  0.060614  0.061917  0.062987  0.064147  0.065100  0.065855  0.066392
# 4410  0.452216  0.458328  0.465438  0.472127  0.478453  0.482693  0.485724
# 4411  0.120796  0.119629  0.118778  0.118579  0.119050  0.119392  0.120985
#
# [4412 rows x 14 columns]

# %%
pd.DataFrame(data.mean(axis=0))
# Out:
#                  0
# origin    0.171826
# layer 0   0.192283
# layer 1   0.193251
# layer 2   0.195438
# layer 3   0.198133
# layer 4   0.200854
# layer 5   0.203753
# layer 6   0.205689
# layer 7   0.207558
# layer 8   0.210171
# layer 9   0.212760
# layer 10  0.215251
# layer 11  0.217566
# layer 12  0.219610

# %%
pd.DataFrame(data.loc[positive_effect].mean(axis=0))
# Out:
#                  0
# origin    0.207207
# layer 0   0.231444
# layer 1   0.233671
# layer 2   0.235546
# layer 3   0.239476
# layer 4   0.243829
# layer 5   0.247630
# layer 6   0.249928
# layer 7   0.252662
# layer 8   0.256056
# layer 9   0.259226
# layer 10  0.261785
# layer 11  0.264115
# layer 12  0.266808

# %%
pd.DataFrame(data.loc[negative_effect].mean(axis=0))
# Out:
#                  0
# origin    0.167385
# layer 0   0.187368
# layer 1   0.188178
# layer 2   0.190404
# layer 3   0.192944
# layer 4   0.195460
# layer 5   0.198246
# layer 6   0.200136
# layer 7   0.201896
# layer 8   0.204412
# layer 9   0.206927
# layer 10  0.209410
# layer 11  0.211724
# layer 12  0.213687

# %%
prob_data = pd.read_csv('./dataset/intervention_data/gpt2_train=False_edit_indiv_prob.csv') 
prob_data
# Out:
#         origin   layer 0   layer 1   layer 2   layer 3   layer 4   layer 5  \
# 0     0.060381  0.082839  0.060495  0.060377  0.062129  0.061211  0.060973
# 1     0.254463  0.250577  0.254197  0.253095  0.256067  0.258944  0.260221
# 2     0.054926  0.068459  0.054905  0.056016  0.055373  0.054905  0.054804
# 3     0.054664  0.058539  0.054671  0.054440  0.055515  0.055097  0.054580
# 4     0.131792  0.131748  0.143291  0.136761  0.135629  0.135872  0.137176
# ...        ...       ...       ...       ...       ...       ...       ...
# 4407  0.078260  0.114105  0.078135  0.079407  0.079605  0.079280  0.078594
# 4408  0.154431  0.193971  0.153942  0.156903  0.157001  0.158598  0.157096
# 4409  0.045767  0.054514  0.045499  0.045889  0.046142  0.047060  0.045469
# 4410  0.323204  0.415390  0.324386  0.327605  0.329787  0.328713  0.329233
# 4411  0.073940  0.111856  0.073871  0.075247  0.074961  0.075123  0.074853
#
#        layer 6   layer 7   layer 8   layer 9  layer 10  layer 11  layer 12
# 0     0.059565  0.060655  0.059364  0.060098  0.059760  0.059640  0.061886
# 1     0.256439  0.254531  0.257325  0.257409  0.254094  0.253930  0.255330
# 2     0.054565  0.053896  0.053879  0.054672  0.054834  0.054651  0.055585
# 3     0.054469  0.054495  0.053992  0.054194  0.054548  0.054597  0.055087
# 4     0.140013  0.142293  0.142529  0.142856  0.143645  0.143246  0.145894
# ...        ...       ...       ...       ...       ...       ...       ...
# 4407  0.077486  0.078146  0.078355  0.078775  0.078552  0.078839  0.079068
# 4408  0.154600  0.153310  0.153928  0.154099  0.154308  0.154973  0.156618
# 4409  0.045434  0.045121  0.045765  0.045764  0.045488  0.045653  0.045655
# 4410  0.325652  0.327533  0.328158  0.327866  0.327499  0.326130  0.326245
# 4411  0.073611  0.073111  0.073163  0.073630  0.074216  0.074148  0.075032
#
# [4412 rows x 14 columns]

# %%
display(pd.DataFrame(prob_data.mean(axis=0)))
# Out:
#                  0
# origin    0.171826
# layer 0   0.192283
# layer 1   0.172304
# layer 2   0.173329
# layer 3   0.174137
# layer 4   0.174091
# layer 5   0.174193
# layer 6   0.173303
# layer 7   0.173220
# layer 8   0.173778
# layer 9   0.173666
# layer 10  0.173474
# layer 11  0.173443
# layer 12  0.173284

# %%
display(pd.DataFrame(prob_data.loc[positive_effect].mean(axis=0)))
# Out:
#                  0
# origin    0.207207
# layer 0   0.231444
# layer 1   0.208827
# layer 2   0.208526
# layer 3   0.211027
# layer 4   0.211393
# layer 5   0.210994
# layer 6   0.209485
# layer 7   0.209624
# layer 8   0.210124
# layer 9   0.209886
# layer 10  0.209072
# layer 11  0.209004
# layer 12  0.209287

# %%
display(pd.DataFrame(prob_data.loc[negative_effect].mean(axis=0)))
# Out:
#                  0
# origin    0.167385
# layer 0   0.187368
# layer 1   0.167720
# layer 2   0.168912
# layer 3   0.169507
# layer 4   0.169409
# layer 5   0.169574
# layer 6   0.168761
# layer 7   0.168651
# layer 8   0.169216
# layer 9   0.169120
# layer 10  0.169006
# layer 11  0.168980
# layer 12  0.168766

# %%
import os
os.getcwd()
# Out:
# '/data1/sjlee/NLP/Experiment8'

# %%
display(pd.read_csv('./dataset/intervention_data/gpt2_train=False_edit_accuracy__prob.csv'))
# Out:
#     total_stacked  pos_stacked  neg_stacked  total_indiv  pos_indiv  neg_indiv
# 0        0.060517     0.156504     0.048469     0.060517   0.156504   0.048469
# 1        0.045331     0.140244     0.033418     0.045331   0.140244   0.033418
# 2        0.043971     0.132114     0.032908     0.059383   0.154472   0.047449
# 3        0.042384     0.130081     0.031378     0.058930   0.156504   0.046684
# 4        0.042158     0.130081     0.031122     0.058704   0.154472   0.046684
# 5        0.041931     0.130081     0.030867     0.059383   0.154472   0.047449
# 6        0.040798     0.128049     0.029847     0.058704   0.154472   0.046684
# 7        0.040798     0.128049     0.029847     0.059610   0.154472   0.047704
# 8        0.040118     0.119919     0.030102     0.059383   0.154472   0.047449
# 9        0.038531     0.111789     0.029337     0.058930   0.154472   0.046939
# 10       0.038305     0.105691     0.029847     0.059157   0.154472   0.047194
# 11       0.037171     0.097561     0.029592     0.058477   0.154472   0.046429
# 12       0.036945     0.095528     0.029592     0.058704   0.156504   0.046429
# 13       0.035811     0.087398     0.029337     0.059610   0.156504   0.047449

# %% [markdown]
# # Train=True

# %%
total_data = pd.read_csv('./dataset/intervention_data/gpt2_train=True_Total.csv')
total_data
# Out:
#           prob        kl   entropy
# 0     0.146471  4.069785  6.057753
# 1     0.424571  7.348496  6.174748
# 2     0.992279  9.834436  9.314149
# 3     0.148583  6.131197  5.689916
# 4     0.367218  0.316818  1.718099
# ...        ...       ...       ...
# 4407  0.466487  5.844389  8.094136
# 4408  0.512915  5.370334  7.713697
# 4409  0.380489  8.613902  6.744452
# 4410  0.487833  7.254220  6.955940
# 4411  0.115202  3.830449  5.656858
#
# [4412 rows x 3 columns]

# %%
pd.DataFrame(total_data.mean())
# Out:
#                 0
# prob     0.449066
# kl       6.103899
# entropy  6.316039

# %%
positive_effect = total_data.loc[total_data['prob']>0].index
negative_effect = total_data.loc[total_data['prob']<0].index

# %%
print(len(positive_effect))
print(len(negative_effect))
# Out:
# 4278
# 134

# %%
pd.DataFrame(total_data.iloc[positive_effect].mean())
# Out:
#                 0
# prob     0.466258
# kl       6.204546
# entropy  6.494847

# %%
pd.DataFrame(total_data.iloc[negative_effect].mean())
# Out:
#                 0
# prob    -0.099803
# kl       2.890695
# entropy  0.607537

# %%
data = pd.read_csv('./dataset/intervention_data/gpt2_train=True_edit_prob.csv') 
data
# Out:
#         origin   layer 0   layer 1   layer 2   layer 3   layer 4   layer 5  \
# 0     0.151096  0.152429  0.152317  0.152101  0.151955  0.151896  0.151806
# 1     0.441099  0.447970  0.448016  0.447862  0.447935  0.447932  0.447755
# 2     0.999650  0.999748  0.999755  0.999760  0.999762  0.999767  0.999774
# 3     0.178396  0.179607  0.180112  0.180592  0.181184  0.181324  0.181389
# 4     0.702637  0.702628  0.705024  0.708203  0.711846  0.715829  0.720007
# ...        ...       ...       ...       ...       ...       ...       ...
# 4407  0.475619  0.466756  0.466462  0.466256  0.465788  0.465131  0.464188
# 4408  0.518963  0.508495  0.508033  0.506949  0.505532  0.504513  0.504113
# 4409  0.435542  0.459493  0.460495  0.461225  0.461822  0.462386  0.462801
# 4410  0.500783  0.491722  0.490514  0.489907  0.489845  0.488985  0.488045
# 4411  0.120001  0.121479  0.121568  0.121348  0.121188  0.121135  0.121163
#
#        layer 6   layer 7   layer 8   layer 9  layer 10  layer 11  layer 12
# 0     0.151813  0.151854  0.151882  0.151865  0.152149  0.152447  0.152762
# 1     0.448157  0.448561  0.449351  0.449466  0.448854  0.449219  0.448850
# 2     0.999780  0.999787  0.999794  0.999800  0.999805  0.999808  0.999809
# 3     0.181391  0.181397  0.181192  0.181287  0.181193  0.181239  0.181203
# 4     0.724291  0.729161  0.734216  0.739359  0.744326  0.749091  0.753506
# ...        ...       ...       ...       ...       ...       ...       ...
# 4407  0.463176  0.461856  0.460518  0.459580  0.458823  0.458306  0.458754
# 4408  0.503986  0.504042  0.503823  0.504576  0.504743  0.504781  0.504182
# 4409  0.462997  0.462386  0.461958  0.461394  0.460791  0.460219  0.459616
# 4410  0.487361  0.486622  0.486460  0.486417  0.486720  0.487308  0.487982
# 4411  0.121308  0.121356  0.121511  0.121741  0.122047  0.122370  0.122841
#
# [4412 rows x 14 columns]

# %%
display(pd.DataFrame(data.mean(axis=0)))
# Out:
#                  0
# origin    0.488085
# layer 0   0.488834
# layer 1   0.488941
# layer 2   0.489060
# layer 3   0.489180
# layer 4   0.489299
# layer 5   0.489403
# layer 6   0.489500
# layer 7   0.489622
# layer 8   0.489773
# layer 9   0.489979
# layer 10  0.490236
# layer 11  0.490566
# layer 12  0.490957

# %%
pd.DataFrame(data.loc[positive_effect].mean(axis=0))
# Out:
#                  0
# origin    0.498231
# layer 0   0.499006
# layer 1   0.499087
# layer 2   0.499172
# layer 3   0.499254
# layer 4   0.499333
# layer 5   0.499394
# layer 6   0.499444
# layer 7   0.499516
# layer 8   0.499615
# layer 9   0.499759
# layer 10  0.499944
# layer 11  0.500202
# layer 12  0.500519

# %%
pd.DataFrame(data.loc[negative_effect].mean(axis=0))
# Out:
#                  0
# origin    0.164195
# layer 0   0.164094
# layer 1   0.165034
# layer 2   0.166229
# layer 3   0.167547
# layer 4   0.168959
# layer 5   0.170447
# layer 6   0.172043
# layer 7   0.173727
# layer 8   0.175554
# layer 9   0.177748
# layer 10  0.180323
# layer 11  0.182945
# layer 12  0.185671

# %%
prob_data = pd.read_csv('./dataset/intervention_data/gpt2_train=True_edit_indiv_prob.csv') 
prob_data
# Out:
#         origin   layer 0   layer 1   layer 2   layer 3   layer 4   layer 5  \
# 0     0.151096  0.152429  0.151022  0.150904  0.150918  0.151029  0.151056
# 1     0.441099  0.447970  0.441257  0.441073  0.441197  0.441299  0.441105
# 2     0.999650  0.999748  0.999665  0.999660  0.999657  0.999663  0.999663
# 3     0.178396  0.179607  0.178835  0.178920  0.178962  0.178540  0.178476
# 4     0.702637  0.702628  0.705072  0.705857  0.706245  0.706666  0.706967
# ...        ...       ...       ...       ...       ...       ...       ...
# 4407  0.475619  0.466756  0.475459  0.475489  0.475222  0.474992  0.474753
# 4408  0.518963  0.508495  0.518503  0.517992  0.517487  0.518307  0.518722
# 4409  0.435542  0.459493  0.436372  0.436018  0.436028  0.435996  0.435834
# 4410  0.500783  0.491722  0.499283  0.500313  0.500917  0.500047  0.499919
# 4411  0.120001  0.121479  0.120106  0.119908  0.119840  0.119982  0.120112
#
#        layer 6   layer 7   layer 8   layer 9  layer 10  layer 11  layer 12
# 0     0.151109  0.151106  0.151122  0.151064  0.151344  0.151443  0.151365
# 1     0.441641  0.441708  0.441877  0.441339  0.440719  0.441550  0.440770
# 2     0.999661  0.999663  0.999663  0.999662  0.999659  0.999656  0.999651
# 3     0.178334  0.178236  0.178207  0.178462  0.178310  0.178392  0.178350
# 4     0.707199  0.707714  0.707939  0.708161  0.707985  0.707917  0.707548
# ...        ...       ...       ...       ...       ...       ...       ...
# 4407  0.474715  0.474353  0.474322  0.474678  0.474809  0.475097  0.476071
# 4408  0.519013  0.519212  0.518929  0.519909  0.519217  0.518922  0.518467
# 4409  0.435659  0.434916  0.435026  0.435007  0.434894  0.435110  0.435114
# 4410  0.500086  0.500101  0.500694  0.500782  0.501144  0.501320  0.501475
# 4411  0.120183  0.120050  0.120175  0.120248  0.120341  0.120298  0.120482
#
# [4412 rows x 14 columns]

# %%
pd.DataFrame(prob_data.mean(axis=0))
# Out:
#                  0
# origin    0.488085
# layer 0   0.488834
# layer 1   0.488229
# layer 2   0.488248
# layer 3   0.488249
# layer 4   0.488254
# layer 5   0.488233
# layer 6   0.488227
# layer 7   0.488251
# layer 8   0.488277
# layer 9   0.488314
# layer 10  0.488347
# layer 11  0.488416
# layer 12  0.488461

# %%
pd.DataFrame(prob_data.loc[positive_effect].mean(axis=0))
# Out:
#                  0
# origin    0.498231
# layer 0   0.499006
# layer 1   0.498349
# layer 2   0.498360
# layer 3   0.498357
# layer 4   0.498361
# layer 5   0.498339
# layer 6   0.498331
# layer 7   0.498353
# layer 8   0.498378
# layer 9   0.498412
# layer 10  0.498445
# layer 11  0.498515
# layer 12  0.498562

# %%
pd.DataFrame(prob_data.loc[negative_effect].mean(axis=0))
# Out:
#                  0
# origin    0.164195
# layer 0   0.164094
# layer 1   0.165162
# layer 2   0.165416
# layer 3   0.165535
# layer 4   0.165584
# layer 5   0.165594
# layer 6   0.165668
# layer 7   0.165736
# layer 8   0.165811
# layer 9   0.165938
# layer 10  0.165982
# layer 11  0.166004
# layer 12  0.165997

# %%
display(pd.read_csv('./dataset/intervention_data/gpt2_train=True_edit_accuracy__prob.csv'))
# Out:
#     total_stacked  pos_stacked  neg_stacked  total_indiv  pos_indiv  neg_indiv
# 0        0.420444     0.431744     0.059701     0.420444   0.431744   0.059701
# 1        0.421124     0.431978     0.074627     0.421124   0.431978   0.074627
# 2        0.421124     0.431978     0.074627     0.420671   0.431744   0.067164
# 3        0.420671     0.431744     0.067164     0.420671   0.431744   0.067164
# 4        0.420671     0.431744     0.067164     0.420444   0.431744   0.059701
# 5        0.420671     0.431744     0.067164     0.420444   0.431744   0.059701
# 6        0.420671     0.431744     0.067164     0.420444   0.431744   0.059701
# 7        0.420444     0.431510     0.067164     0.420218   0.431744   0.052239
# 8        0.420671     0.431744     0.067164     0.420671   0.431744   0.067164
# 9        0.421124     0.431978     0.074627     0.420671   0.431744   0.067164
# 10       0.421124     0.431978     0.074627     0.420444   0.431744   0.059701
# 11       0.421124     0.431978     0.074627     0.420444   0.431744   0.059701
# 12       0.421124     0.431978     0.074627     0.420444   0.431744   0.059701
# 13       0.421124     0.431978     0.074627     0.420444   0.431744   0.059701
