# %% [markdown]
# # Entropy

# %%
import pandas as pd

# %%
total_data = pd.read_csv('./dataset/intervention_data/gpt2_train=False_Total.csv')
total_data
# Out:
#           prob         kl   entropy
# 0    -0.811730  11.324991 -4.458462
# 1    -0.079996  12.253328  0.312050
# 2    -0.873690  11.862528 -6.046141
# 3    -0.629521  12.853862 -4.754339
# 4    -0.086813   0.231026  0.206219
# ...        ...        ...       ...
# 4407 -0.689437  11.481072 -3.619538
# 4408 -0.738699  11.887397 -4.413545
# 4409 -0.063761  10.935291 -0.679931
# 4410 -0.670067  13.116758 -4.840611
# 4411 -0.840015  11.939545 -4.412962
#
# [4412 rows x 3 columns]

# %%
pd.DataFrame(total_data.mean())
# Out:
#                  0
# prob     -0.553152
# kl       11.482063
# entropy  -3.615316

# %%
positive_effect = total_data.loc[total_data['entropy']>0].index
negative_effect = total_data.loc[total_data['entropy']<0].index

# %%
print(len(positive_effect))
print(len(negative_effect))
# Out:
# 648
# 3764

# %%
display(pd.DataFrame(total_data.iloc[positive_effect].mean()))
display(pd.DataFrame(total_data.iloc[negative_effect].mean()))
# Out:
#                 0
# prob     0.020973
# kl       7.218677
# entropy  0.685539
#                  0
# prob     -0.651992
# kl       12.216036
# entropy  -4.355740

# %% [markdown]
# # Train = False

# %%
data = pd.read_csv('./dataset/intervention_data/gpt2_train=False_edit_entropy.csv') 
data
# Out:
#         origin   layer 0   layer 1   layer 2   layer 3   layer 4   layer 5  \
# 0     5.585329  5.501854  5.501585  5.490339  5.483059  5.485302  5.486468
# 1     4.494078  4.504732  4.505988  4.514939  4.508907  4.495143  4.460607
# 2     6.701682  6.655242  6.654449  6.647979  6.640606  6.636024  6.620164
# 3     7.300532  7.280986  7.286448  7.294393  7.267193  7.251574  7.239522
# 4     4.760793  4.760947  4.668477  4.584102  4.510064  4.436268  4.354309
# ...        ...       ...       ...       ...       ...       ...       ...
# 4407  5.512606  5.398978  5.396955  5.391225  5.381733  5.373569  5.364693
# 4408  5.374681  5.213850  5.213955  5.200054  5.181602  5.160274  5.144221
# 4409  6.837010  6.632192  6.608515  6.598560  6.603845  6.606318  6.588272
# 4410  4.915978  4.152105  4.131448  4.082079  4.017171  3.955954  3.889325
# 4411  5.205304  5.111792  5.112919  5.106891  5.094341  5.082390  5.075072
#
#        layer 6   layer 7   layer 8   layer 9  layer 10  layer 11  layer 12
# 0     5.497447  5.512583  5.530416  5.546225  5.548764  5.541456  5.545060
# 1     4.449335  4.443262  4.426856  4.404140  4.390861  4.381485  4.374203
# 2     6.608141  6.597274  6.597726  6.584255  6.574784  6.560677  6.555259
# 3     7.230793  7.230002  7.227406  7.223933  7.220520  7.216663  7.214643
# 4     4.271291  4.181218  4.085785  3.998016  3.920082  3.851187  3.783886
# ...        ...       ...       ...       ...       ...       ...       ...
# 4407  5.359591  5.367110  5.368729  5.367556  5.365566  5.362992  5.360723
# 4408  5.142492  5.147734  5.151033  5.149697  5.145470  5.142432  5.134330
# 4409  6.565678  6.538946  6.505313  6.461604  6.421153  6.379938  6.365014
# 4410  3.851665  3.801143  3.739754  3.679816  3.621851  3.579242  3.555809
# 4411  5.075409  5.075182  5.075469  5.073285  5.069572  5.064352  5.062041
#
# [4412 rows x 14 columns]

# %%
pd.DataFrame(data.mean(axis=0))
# Out:
#                  0
# origin    5.639613
# layer 0   5.463302
# layer 1   5.452717
# layer 2   5.432541
# layer 3   5.407438
# layer 4   5.380989
# layer 5   5.351595
# layer 6   5.328568
# layer 7   5.307108
# layer 8   5.279393
# layer 9   5.248043
# layer 10  5.220319
# layer 11  5.193525
# layer 12  5.179535

# %%
pd.DataFrame(data.loc[positive_effect].mean(axis=0))
# Out:
#                  0
# origin    5.223690
# layer 0   5.022728
# layer 1   4.982155
# layer 2   4.945303
# layer 3   4.905827
# layer 4   4.857693
# layer 5   4.801858
# layer 6   4.749041
# layer 7   4.694594
# layer 8   4.632416
# layer 9   4.570807
# layer 10  4.517107
# layer 11  4.466113
# layer 12  4.429764

# %%
pd.DataFrame(data.loc[negative_effect].mean(axis=0))
# Out:
#                  0
# origin    5.711217
# layer 0   5.539150
# layer 1   5.533728
# layer 2   5.516423
# layer 3   5.493793
# layer 4   5.471078
# layer 5   5.446237
# layer 6   5.428338
# layer 7   5.412556
# layer 8   5.390775
# layer 9   5.364635
# layer 10  5.341382
# layer 11  5.318754
# layer 12  5.308613

# %%
prob_data = pd.read_csv('./dataset/intervention_data/gpt2_train=False_edit_indiv_entropy.csv') 
prob_data
# Out:
#         origin   layer 0   layer 1   layer 2   layer 3   layer 4   layer 5  \
# 0     5.585329  5.501854  5.585499  5.573250  5.583523  5.592767  5.594927
# 1     4.494078  4.504732  4.497695  4.506786  4.487001  4.475945  4.455035
# 2     6.701682  6.655242  6.700054  6.698677  6.697339  6.700196  6.683763
# 3     7.300532  7.280986  7.309204  7.314214  7.266205  7.282691  7.285830
# 4     4.760793  4.760947  4.668288  4.689248  4.689274  4.687656  4.677843
# ...        ...       ...       ...       ...       ...       ...       ...
# 4407  5.512606  5.398978  5.514650  5.516254  5.507986  5.508706  5.505188
# 4408  5.374681  5.213850  5.375635  5.368324  5.360883  5.359944  5.365932
# 4409  6.837010  6.632192  6.828995  6.836936  6.844168  6.841767  6.831532
# 4410  4.915978  4.152105  4.910292  4.880476  4.860146  4.863326  4.859683
# 4411  5.205304  5.111792  5.207850  5.207413  5.196996  5.196701  5.202050
#
#        layer 6   layer 7   layer 8   layer 9  layer 10  layer 11  layer 12
# 0     5.599826  5.602118  5.603554  5.599597  5.588495  5.575699  5.592706
# 1     4.480165  4.484571  4.476833  4.471078  4.479317  4.485655  4.487574
# 2     6.690472  6.688766  6.701892  6.689696  6.692491  6.685736  6.698026
# 3     7.290509  7.298967  7.295547  7.294497  7.296593  7.296039  7.298938
# 4     4.680506  4.674564  4.668004  4.675510  4.689476  4.701754  4.709643
# ...        ...       ...       ...       ...       ...       ...       ...
# 4407  5.506824  5.522927  5.516998  5.514900  5.512218  5.511243  5.512805
# 4408  5.373769  5.381418  5.379673  5.373730  5.371696  5.372222  5.371005
# 4409  6.826373  6.823957  6.817143  6.810720  6.816660  6.813183  6.826757
# 4410  4.889010  4.875885  4.867218  4.869835  4.872084  4.879145  4.891871
# 4411  5.206177  5.202943  5.203792  5.202485  5.202926  5.200647  5.206527
#
# [4412 rows x 14 columns]

# %%
display(pd.DataFrame(prob_data.mean(axis=0)))
# Out:
#                  0
# origin    5.639613
# layer 0   5.463302
# layer 1   5.634110
# layer 2   5.625623
# layer 3   5.616772
# layer 4   5.615613
# layer 5   5.613441
# layer 6   5.619347
# layer 7   5.620477
# layer 8   5.615594
# layer 9   5.612512
# layer 10  5.616963
# layer 11  5.616571
# layer 12  5.627175

# %%
display(pd.DataFrame(prob_data.loc[positive_effect].mean(axis=0)))
# Out:
#                  0
# origin    5.223690
# layer 0   5.022728
# layer 1   5.190567
# layer 2   5.196154
# layer 3   5.185250
# layer 4   5.176079
# layer 5   5.170124
# layer 6   5.173773
# layer 7   5.172642
# layer 8   5.166560
# layer 9   5.167136
# layer 10  5.177527
# layer 11  5.179743
# layer 12  5.190166

# %%
display(pd.DataFrame(prob_data.loc[negative_effect].mean(axis=0)))
# Out:
#                  0
# origin    5.711217
# layer 0   5.539150
# layer 1   5.710469
# layer 2   5.699559
# layer 3   5.691062
# layer 4   5.691282
# layer 5   5.689761
# layer 6   5.696055
# layer 7   5.697576
# layer 8   5.692899
# layer 9   5.689187
# layer 10  5.692615
# layer 11  5.691774
# layer 12  5.702409

# %%
display(pd.read_csv('./dataset/intervention_data/gpt2_train=False_edit_accuracy__entropy.csv'))
# Out:
#     total_stacked  pos_stacked  neg_stacked  total_indiv  pos_indiv  neg_indiv
# 0        0.060517     0.158951     0.043571     0.060517   0.158951   0.043571
# 1        0.046691     0.129630     0.032412     0.046691   0.129630   0.032412
# 2        0.045331     0.126543     0.031350     0.059837   0.154321   0.043571
# 3        0.044198     0.121914     0.030818     0.058704   0.154321   0.042242
# 4        0.043518     0.120370     0.030287     0.058930   0.154321   0.042508
# 5        0.043291     0.120370     0.030021     0.059157   0.151235   0.043305
# 6        0.041478     0.117284     0.028427     0.058930   0.152778   0.042774
# 7        0.041024     0.114198     0.028427     0.059610   0.154321   0.043305
# 8        0.041251     0.109568     0.029490     0.059837   0.152778   0.043836
# 9        0.040345     0.108025     0.028693     0.059610   0.154321   0.043305
# 10       0.039891     0.101852     0.029224     0.059157   0.152778   0.043039
# 11       0.038531     0.094136     0.028959     0.058704   0.152778   0.042508
# 12       0.037851     0.091049     0.028693     0.058704   0.152778   0.042508
# 13       0.037171     0.091049     0.027896     0.059837   0.155864   0.043305

# %% [markdown]
# # Train=True

# %%
total_data = pd.read_csv('./dataset/intervention_data/gpt2_train=True_Total.csv')
total_data
# Out:
#           prob        kl   entropy
# 0     0.146471  4.069785  6.057753
# 1     0.424571  7.348496  6.174748
# 2     0.992279  9.834436  9.314149
# 3     0.148583  6.131197  5.689916
# 4     0.367218  0.316818  1.718099
# ...        ...       ...       ...
# 4407  0.466487  5.844389  8.094136
# 4408  0.512915  5.370334  7.713697
# 4409  0.380489  8.613902  6.744452
# 4410  0.487833  7.254220  6.955940
# 4411  0.115202  3.830449  5.656858
#
# [4412 rows x 3 columns]

# %%
pd.DataFrame(total_data.mean())
# Out:
#                 0
# prob     0.449066
# kl       6.103899
# entropy  6.316039

# %%
positive_effect = total_data.loc[total_data['entropy']>0].index
negative_effect = total_data.loc[total_data['entropy']<0].index

# %%
print(len(positive_effect))
print(len(negative_effect))
# Out:
# 4380
# 32

# %%
pd.DataFrame(total_data.iloc[positive_effect].mean())
# Out:
#                 0
# prob     0.453219
# kl       6.140617
# entropy  6.364427

# %%
pd.DataFrame(total_data.iloc[negative_effect].mean())
# Out:
#                 0
# prob    -0.119383
# kl       1.078142
# entropy -0.307074

# %%
data = pd.read_csv('./dataset/intervention_data/gpt2_train=True_edit_entropy.csv') 
data
# Out:
#         origin   layer 0   layer 1   layer 2   layer 3   layer 4   layer 5  \
# 0     3.528265  3.523634  3.523010  3.522039  3.520344  3.518388  3.515353
# 1     2.600141  2.587298  2.587876  2.588731  2.589752  2.591277  2.591868
# 2     0.003354  0.002751  0.002703  0.002687  0.002696  0.002680  0.002666
# 3     3.006993  2.983428  2.982384  2.980550  2.977442  2.976478  2.976038
# 4     1.864189  1.864218  1.853103  1.837968  1.820219  1.801798  1.781508
# ...        ...       ...       ...       ...       ...       ...       ...
# 4407  1.259484  1.263592  1.263777  1.263683  1.263167  1.262499  1.262370
# 4408  1.717130  1.751629  1.757174  1.765265  1.771719  1.777742  1.785131
# 4409  1.729754  1.699996  1.698813  1.697224  1.696360  1.694750  1.693747
# 4410  2.038868  2.101540  2.104642  2.105263  2.105595  2.105383  2.105565
# 4411  3.894019  3.900779  3.899303  3.899537  3.899854  3.898376  3.896952
#
#        layer 6   layer 7   layer 8   layer 9  layer 10  layer 11  layer 12
# 0     3.511837  3.508828  3.505297  3.501689  3.496783  3.491823  3.486368
# 1     2.592600  2.592586  2.590909  2.590910  2.590518  2.582919  2.580286
# 2     0.002645  0.002621  0.002622  0.002611  0.002572  0.002540  0.002527
# 3     2.975379  2.974207  2.972892  2.971086  2.968994  2.965795  2.962733
# 4     1.759993  1.735742  1.710498  1.683393  1.657283  1.631191  1.608595
# ...        ...       ...       ...       ...       ...       ...       ...
# 4407  1.261729  1.261340  1.260142  1.259176  1.257814  1.255946  1.253235
# 4408  1.791829  1.797031  1.802551  1.804100  1.803067  1.798139  1.792068
# 4409  1.692111  1.691611  1.691761  1.690990  1.690384  1.688970  1.687485
# 4410  2.106560  2.107221  2.106230  2.105112  2.103076  2.099715  2.093779
# 4411  3.893947  3.890204  3.884927  3.880530  3.873673  3.866541  3.859135
#
# [4412 rows x 14 columns]

# %%
display(pd.DataFrame(data.mean(axis=0)))
# Out:
#                  0
# origin    2.517279
# layer 0   2.521104
# layer 1   2.520415
# layer 2   2.519602
# layer 3   2.518518
# layer 4   2.517103
# layer 5   2.515877
# layer 6   2.514775
# layer 7   2.513271
# layer 8   2.511263
# layer 9   2.508446
# layer 10  2.504470
# layer 11  2.499259
# layer 12  2.493428

# %%
pd.DataFrame(data.loc[positive_effect].mean(axis=0))
# Out:
#                  0
# origin    2.502715
# layer 0   2.506534
# layer 1   2.505919
# layer 2   2.505187
# layer 3   2.504201
# layer 4   2.502878
# layer 5   2.501752
# layer 6   2.500750
# layer 7   2.499349
# layer 8   2.497450
# layer 9   2.494744
# layer 10  2.490875
# layer 11  2.485763
# layer 12  2.480012

# %%
pd.DataFrame(data.loc[negative_effect].mean(axis=0))
# Out:
#                  0
# origin    4.510676
# layer 0   4.515351
# layer 1   4.504645
# layer 2   4.492626
# layer 3   4.478078
# layer 4   4.464166
# layer 5   4.449209
# layer 6   4.434394
# layer 7   4.418809
# layer 8   4.401935
# layer 9   4.383901
# layer 10  4.365228
# layer 11  4.346547
# layer 12  4.329694

# %%
prob_data = pd.read_csv('./dataset/intervention_data/gpt2_train=True_edit_indiv_entropy.csv') 
prob_data
# Out:
#         origin   layer 0   layer 1   layer 2   layer 3   layer 4   layer 5  \
# 0     3.528265  3.523634  3.527051  3.526832  3.526494  3.525700  3.525644
# 1     2.600141  2.587298  2.599869  2.600900  2.601173  2.600562  2.600973
# 2     0.003354  0.002751  0.003271  0.003334  0.003335  0.003307  0.003319
# 3     3.006993  2.983428  3.005269  3.004244  3.003837  3.005494  3.006382
# 4     1.864189  1.864218  1.853210  1.848524  1.846299  1.845164  1.843518
# ...        ...       ...       ...       ...       ...       ...       ...
# 4407  1.259484  1.263592  1.259172  1.259263  1.258733  1.258511  1.259019
# 4408  1.717130  1.751629  1.721875  1.722667  1.722752  1.721855  1.723275
# 4409  1.729754  1.699996  1.728193  1.727780  1.727845  1.727957  1.728731
# 4410  2.038868  2.101540  2.040265  2.038711  2.038666  2.037733  2.038585
# 4411  3.894019  3.900779  3.892301  3.893788  3.893746  3.892261  3.892159
#
#        layer 6   layer 7   layer 8   layer 9  layer 10  layer 11  layer 12
# 0     3.524536  3.525231  3.524657  3.524674  3.523481  3.523296  3.522773
# 1     2.599843  2.599517  2.597635  2.599533  2.598868  2.592632  2.597457
# 2     0.003318  0.003307  0.003342  0.003328  0.003307  0.003316  0.003343
# 3     3.005949  3.005842  3.005203  3.005296  3.004613  3.003378  3.003570
# 4     1.841973  1.839000  1.837523  1.836007  1.836093  1.835958  1.839884
# ...        ...       ...       ...       ...       ...       ...       ...
# 4407  1.259052  1.258806  1.258329  1.258491  1.258268  1.257676  1.256796
# 4408  1.722062  1.720290  1.720709  1.717878  1.715297  1.712322  1.711686
# 4409  1.728166  1.728685  1.729660  1.728917  1.728568  1.728160  1.727697
# 4410  2.038777  2.038703  2.037326  2.037343  2.036290  2.035484  2.032951
# 4411  3.890651  3.889813  3.888887  3.889019  3.887051  3.886670  3.886227
#
# [4412 rows x 14 columns]

# %%
pd.DataFrame(prob_data.mean(axis=0))
# Out:
#                  0
# origin    2.517279
# layer 0   2.521104
# layer 1   2.516245
# layer 2   2.516005
# layer 3   2.515712
# layer 4   2.515403
# layer 5   2.515648
# layer 6   2.515786
# layer 7   2.515369
# layer 8   2.514890
# layer 9   2.514133
# layer 10  2.513038
# layer 11  2.511875
# layer 12  2.511297

# %%
pd.DataFrame(prob_data.loc[positive_effect].mean(axis=0))
# Out:
#                  0
# origin    2.502715
# layer 0   2.506534
# layer 1   2.501760
# layer 2   2.501527
# layer 3   2.501247
# layer 4   2.500932
# layer 5   2.501183
# layer 6   2.501319
# layer 7   2.500904
# layer 8   2.500431
# layer 9   2.499675
# layer 10  2.498574
# layer 11  2.497403
# layer 12  2.496804

# %%
pd.DataFrame(prob_data.loc[negative_effect].mean(axis=0))
# Out:
#                  0
# origin    4.510676
# layer 0   4.515351
# layer 1   4.498923
# layer 2   4.497687
# layer 3   4.495645
# layer 4   4.496149
# layer 5   4.495603
# layer 6   4.495983
# layer 7   4.495258
# layer 8   4.494038
# layer 9   4.493058
# layer 10  4.492784
# layer 11  4.492781
# layer 12  4.494964

# %%
display(pd.read_csv('./dataset/intervention_data/gpt2_train=True_edit_accuracy__entropy.csv'))
# Out:
#     total_stacked  pos_stacked  neg_stacked  total_indiv  pos_indiv  neg_indiv
# 0        0.420444     0.422831      0.09375     0.420444   0.422831    0.09375
# 1        0.420898     0.423288      0.09375     0.420898   0.423288    0.09375
# 2        0.420898     0.423288      0.09375     0.420671   0.423059    0.09375
# 3        0.420671     0.423059      0.09375     0.420671   0.423059    0.09375
# 4        0.420671     0.423059      0.09375     0.420444   0.422831    0.09375
# 5        0.420671     0.423059      0.09375     0.420444   0.422831    0.09375
# 6        0.420671     0.423059      0.09375     0.420444   0.422831    0.09375
# 7        0.420671     0.423059      0.09375     0.420218   0.422603    0.09375
# 8        0.420444     0.422831      0.09375     0.420444   0.422831    0.09375
# 9        0.420218     0.422603      0.09375     0.420671   0.423059    0.09375
# 10       0.420218     0.422603      0.09375     0.420444   0.422831    0.09375
# 11       0.420218     0.422603      0.09375     0.420444   0.422831    0.09375
# 12       0.420444     0.422831      0.09375     0.420671   0.423059    0.09375
# 13       0.420444     0.422831      0.09375     0.420444   0.422831    0.09375
